# %% [markdown]
# Importing libraries for further usage

# %%
# removing warnings
import warnings
warnings.filterwarnings('ignore')

# computational needs
import networkx as nx
import pandas as pd

# local files
import roads

from TurkeyGraph import create_graph

# %% [markdown]
# ## Read City and Road data

# %%
G = create_graph()
# Picture the map
pos = {city:(long, lat) for (city, (lat,long)) in nx.get_node_attributes(G, 'pos').items()}
nx.draw(G, pos, with_labels=False, node_size=10, node_color='r', edge_color='b')
