# %% [markdown]
# Importing libraries for further usage

# %%
# removing warnings
import warnings
warnings.filterwarnings('ignore')

# computational needs
import networkx as nx
import pandas as pd

# scraping for data
import urllib.request
from bs4 import BeautifulSoup 

# plotting
from matplotlib import pyplot as plt

# local files
import roads

# others
from unidecode import unidecode
import random, json
import numpy as np, numpy.random

# %% [markdown]
# useful methods for later

# %%
# CONSTANTS
MAX_JOBS_REFUGEES = 0.7

# %%
def remove_duplicates(seq):
    seen = set()
    seen_add = seen.add
    return [x for x in seq if not (x in seen or seen_add(x))]

def get_job_potential( each):
    """Given a city, give the number of jobs found there."""
    
    # get the url for each city
    URL = "https://tr.indeed.com/jobs?l="+unidecode(each)    
    
    # extract the html, the values from the search
    soup = BeautifulSoup(urllib.request.urlopen(URL).read(), 'html.parser')
    values = soup.find("div", id="JOB_TYPE_rbo")
    
    # find total jobs found in this city
    if values == None: # if no job was found, skip
        return 0
    count = 0
    for li in values.find_all("li"):
        found_jobs = li.find("span", attrs={'class':"rbCount"}).text
        count += int( found_jobs[1:-1])
    return count

def update_info():
    """information about the job market in a all cities"""

    info = {}
    for n in G.nodes:
        # each refugee working knows 10 job openings
        jobs_info = 10 * G.nodes[n]['jobs_to_refugees']/(G.nodes[n]['jobs']+1)
        if jobs_info < 1 and jobs_info > 0.5:
            info[n] = jobs_info
        elif jobs_info <=0.5:
            info[n] = 0.5
        else:
            info[n] = 1.0
    return info

# %% [markdown]
# ## Read City and Road data

# %%
# get city data from the two sources
cities_area = pd.read_csv('cities_area.csv',"\t")
cities_popu = pd.read_csv('cities_popu.csv',",")
cities_subs = pd.read_csv('cities_subs.csv')
cities_empl = pd.read_csv("cities_empl.csv",'\t')

# %%
# get the cities where the main roads pass from in turkey
translate = {}
for e in range(len( cities_subs)):
    translate[ cities_subs.iloc[e]['city'] ] = cities_subs.iloc[e]['admin']
    
# get main roads in Turkey
main_roads = []
for road in roads.get_cities_in_main_roads():
    main_roads.append( remove_duplicates([translate[i] for i in road]))
    
main_cities = list(cities_subs[ cities_subs['city'] == cities_subs['admin']]['city'])
all_cities = set(sum(main_roads, [])+ main_cities)

# %%
# merge the two data
cities = pd.merge( cities_subs[['city','lat','lng']], cities_area[['Name','Area(km²)']]
                    , how='outer', left_on='city', right_on='Name')
cities['old'] = [unidecode(i)  if str(i)!= 'nan' else 'NaN' for i in list(cities['Name'])  ]
new_cities = pd.merge( cities, cities_popu, how='outer',left_on='old', right_on='asciiname')
cities = new_cities[ new_cities['city'].isin(all_cities)].reset_index()
cities = cities[['city','lat','lng','Area(km²)','population']]

# %%
cities_empl = cities_empl.rename(columns={ "İl adı Province name":"city",    "Oran Rate (%)":"Labour",
                                         'Oran Rate (%).1':"Unemployment", 'Oran Rate (%).2':"Employment"})
cities_empl = cities_empl[['city','Labour','Unemployment','Employment']]
cities = pd.merge( cities, cities_empl, how="outer")
cities
# Out:
#               city        lat        lng Area(km²)  population  Labour  \
# 0         İstanbul  41.011046  28.957798     5,196  14804116.0    52.2
# 1           Ankara  39.911652  32.840305    24,521   3517182.0    49.5
# 2            İzmir  38.412726  27.138376    12,012   2500603.0    55.9
# 3            Bursa  40.195593  29.060130    10,422   1412701.0    51.4
# 4            Adana  37.001667  35.328889    13,915   1248988.0    49.9
# 5        Gaziantep  37.059444  37.382500     6,819   1065975.0    46.8
# 6            Konya  37.871354  32.484636    38,873    875530.0    48.4
# 7          Antalya  36.908118  30.695565    20,723    758188.0    57.5
# 8          Trabzon  41.005000  39.726944     4,664    244083.0    50.3
# 9       Diyarbakır  37.913629  40.217213    15,058    644763.0    37.2
# 10          Samsun  41.286667  36.330000     9,083    394050.0    50.5
# 11         Kayseri  38.732222  35.485278    17,043    592840.0    51.0
# 12       Eskişehir  39.776667  30.520556    13,842    514869.0    46.9
# 13         Kocaeli  40.766944  29.916944     3,612   1780000.0    54.8
# 14         Malatya  38.350183  38.316669    11,776    441805.0    54.1
# 15       Şanlıurfa  37.167080  38.793919    18,765    449549.0    38.7
# 16         Erzurum  39.908611  41.276944    25,323    420691.0    50.0
# 17   Kahramanmaraş  37.584705  36.926405    14,346    376045.0    47.0
# 18         Denizli  37.774167  29.087500    11,692    313238.0    57.7
# 19             Van  38.494565  43.383231    19,299    371713.0    46.2
# 20           Hatay  36.206551  36.157225     5,828    305564.0    45.9
# 21          Batman  37.887378  41.132208     4,659    381990.0    36.2
# 22         Sakarya  40.780556  30.403333     4,838    990214.0    54.8
# 23            Rize  41.020833  40.521944     3,922     92772.0    51.5
# 24          Elazığ  38.674314  39.223206     8,455    298004.0    53.1
# 25           Sivas  39.748333  37.016111    28,549    264022.0    49.7
# 26       Balıkesir  39.649167  27.886111    14,299    238151.0    47.2
# 27          Manisa  38.612018  27.426465    13,096    243971.0    55.5
# 28        Adıyaman  37.764410  38.276287     7,033    223744.0    43.1
# 29       Kırıkkale  39.845278  33.506389     4,534    211138.0    44.7
# ..             ...        ...        ...       ...         ...     ...
# 51             Muş  38.731635  41.484821     8,059     82536.0    46.0
# 52           Kilis  36.716111  37.115000     1,428     82301.0    44.5
# 53          Bingöl  38.884722  40.493889     8,253     80568.0    54.6
# 54         Hakkari  37.574444  43.740833     7,179     77699.0    45.2
# 55            Kars  40.598250  43.085477    10,127     77486.0    59.5
# 56        Nevşehir  38.625000  34.712222     5,379     75527.0    50.5
# 57         Çankırı  40.599951  33.615301     7,490    186074.0    45.5
# 58          Mardin  37.313092  40.743569     8,806     71373.0    37.4
# 59       Kastamonu  41.378052  33.775275    13,153     70402.0    47.2
# 60          Burdur  37.720278  30.290833     6,840     66158.0    58.9
# 61          Bitlis  38.401146  42.107845     7,021     46111.0    46.5
# 62      Kırklareli  41.735082  27.225210     6,278     58223.0    53.8
# 63           Muğla  37.218066  28.366497    12,851     48183.0    55.5
# 64         Bilecik  40.141924  29.979319     4,302     40285.0    51.6
# 65           Sinop  42.026829  35.162525     5,792     34834.0    46.4
# 66       Gümüşhane  40.460009  39.471764     6,437    170173.0    49.9
# 67         Tunceli  39.099212  39.543511     7,432     29062.0    54.0
# 68          Artvin  41.181611  41.821722     7,367     24266.0    50.7
# 69           Siirt  37.902420  41.722230     5,473    114034.0    37.5
# 70         Bayburt  40.256313  40.222887     3,739     31258.0    51.3
# 71        Osmaniye  37.074167  36.247778     3,124    202837.0    43.9
# 72          Yalova  40.655015  29.276933       847     71289.0    52.7
# 73         Ardahan  41.108711  42.702222     4,842     21020.0    62.8
# 74          Bartın  41.635833  32.337500     2,080     37427.0    58.5
# 75           Düzce  40.838889  31.163889     2,567     57739.0    56.6
# 76         Aksaray  38.372550  34.025370     7,570    152201.0    50.1
# 77          Şırnak  37.513930  42.454324     7,152     52743.0    37.6
# 78  Afyonkarahisar  38.756667  30.543333    14,314    146136.0    54.1
# 79          Mersin  36.800392  34.612812    15,485    537842.0    50.7
# 80           Iğdır  39.923708  44.044999     3,588     75721.0    58.6
#
#     Unemployment  Employment
# 0           11.2        46.4
# 1           10.2        44.5
# 2           15.4        47.3
# 3            6.6        48.0
# 4           13.2        43.3
# 5            6.9        43.6
# 6            4.7        46.2
# 7            7.9        52.9
# 8            7.4        46.6
# 9           18.7        30.2
# 10           6.6        47.2
# 11           9.9        46.0
# 12           8.5        42.9
# 13          10.1        49.2
# 14           7.8        49.9
# 15          16.3        32.4
# 16           6.6        46.7
# 17          11.6        41.5
# 18           6.5        54.0
# 19          10.3        41.4
# 20          12.2        40.3
# 21          23.4        27.8
# 22           9.4        49.7
# 23           6.7        48.1
# 24           7.8        48.9
# 25          10.0        44.7
# 26           6.0        44.4
# 27           5.1        52.7
# 28           9.1        39.2
# 29           8.0        41.1
# ..           ...         ...
# 51          10.4        41.2
# 52           7.7        41.1
# 53           7.0        50.8
# 54          11.7        39.9
# 55           6.6        55.5
# 56           6.0        47.5
# 57           6.8        42.4
# 58          20.6        29.7
# 59           6.2        44.2
# 60           6.9        54.9
# 61          10.6        41.5
# 62           8.0        49.5
# 63           7.3        51.5
# 64           6.5        48.2
# 65           6.2        43.5
# 66           7.2        46.3
# 67           8.1        49.7
# 68           7.1        47.1
# 69          20.5        29.8
# 70           6.2        48.1
# 71          14.0        37.8
# 72          11.0        46.9
# 73           5.8        59.1
# 74           6.2        54.9
# 75           8.7        51.7
# 76           5.8        47.2
# 77          20.1        30.0
# 78           5.6        51.1
# 79          12.4        44.4
# 80           6.9        54.5
#
# [81 rows x 8 columns]

# %% [markdown]
# ### Put these cities in the map

# %%
# Put everything in a graph
G = nx.Graph()

# create each city
for city in list(cities['city']):
    
    # get number of jobs for this city
    job_potential = get_job_potential( city)
    
    # find position of city in map
    city_properties = cities[cities['city'] == city].iloc[0]
    
    # add the city to the graph
    G.add_node( city_properties['city'], 
               pos =    ( city_properties[ 'lat'], city_properties[ 'lng']), 
               size= int( city_properties[ 'population']),
               area= int( city_properties[ 'Area(km²)'].replace(',','')),
               unem= int( city_properties[ 'Unemployment']),
               refugees=0, jobs_to_refugees=0,
               jobs=job_potential*100)

# %% [markdown]
# ### Connect the cities

# %%
# put the edges connecting the cities

# if found city in road, but not in data, fix manually
for road in main_roads:
    # if any of the paths is not in the list, then mention it, fix it manually
    for each in road:
        if each not in list(cities['city']):
            print("City not found in list: ",each) # TODO: deal automatically
            
    # remind the cities that are present
    for i in range(len(road)-1):
        # add a connection between each two cities
        G.add_edge( road[i], road[i+1], weight=10)
        
# connect the cities not in the list with the closest city in the list
not_found = set( main_cities)- set(sum(main_roads, []))

for each in not_found:
    city = cities[ cities['city'] == each].iloc[0]
    
    # order cities present in list by distance to this city
    found = cities[cities['city'].isin( all_cities)]
    found['distance'] = ((found['lat']-city['lat'])**2 + (found['lng']-city['lng'])**2)
    closest_city = found.sort_values('distance').iloc[1]['city'] # get the closest
    
    # add road connecting these cities
    G.add_edge( city['city'], closest_city, weight=10)

# %% [markdown]
# ### Get the zone where the refugees enter, connect those cities

# %%
# suggest area from Adana to Van
max_lat = cities[cities['city'] ==  'Van']['lat'].iloc[0]
max_lng = cities[cities['city'] ==  'Van']['lng'].iloc[0]
min_lng = cities[cities['city'] =='Adana']['lng'].iloc[0]

# filter
syrian_zone = list(cities[ ( cities[ 'lng'] <= max_lng) & 
                           ( cities[ 'lng'] >= min_lng) & 
                           ( cities[ 'lat'] <= max_lat)]['city'])

# connect all cities close to Syria with the closest cities in this area
for each in syrian_zone:
    
    city = cities[ cities['city'] == each].iloc[0]
    
    # order cities present in list by distance to this city
    found = cities[cities['city'].isin( [n for n in syrian_zone if n != each])]
    found['distance'] = ((found['lat']-city['lat'])**2 + (found['lng']-city['lng'])**2)
    closest_cities = found.sort_values('distance') 
    
    # add road connecting these cities
    # keep the weight lower to suggest less people can move in between
    G.add_edge( city['city'], closest_cities.iloc[0]['city'], weight=100)

# %%
# Picture the map
pos = {city:(long, lat) for (city, (lat,long)) in nx.get_node_attributes(G, 'pos').items()}
nx.draw(G, pos, with_labels=False, node_size=10, node_color='g', edge_color='b')

# %% [markdown]
# ### Start adding refugees depending on time

# %%
# define the zone where the refugees enter
# entrance dates for the refugees
entries = [0]+list( pd.read_json("syrian_refugees.json")['individuals'])
plt.plot( entries)

# working potential
# males that are able to work are in the age range 18-59, 50% of them need a job
# females that are able to work are in the age range 18-59, 10 % of them can deal with a job
# what is the percentage of people able to work?
with open( "distribution.json") as f:
    d = json.load(f)
work_percentage = (int(d['data'][0]['male_1859'])*0.5 
                   + int(d['data'][0]['female_1859'])*0.1)/int(d['data'][0]['individuals'])

# %% [markdown]
# ### Getting a job
# It is easier to get a job, once other refugees work in the same city (Job information). <br>
# If the city is small, the chances decrease. <br>
# If the number of refugees in the city is really high in proportion to the city's population, then your chances decrease.

# %%
for run in range(1,len(entries)):
    
    # get the refugees difference from last run 
    diff = entries[run]-entries[run-1]
    distribute_refugees = np.random.dirichlet(\
                          np.ones( len( syrian_zone)), size=1)[0] * diff
    refugees = [int(n) for n in distribute_refugees]
    
    # put these people in the city
    for i in range(len(syrian_zone)):
        n = syrian_zone[i] # city close to syria
        G.nodes[ n]['refugees'] += refugees[i]
    
    # check other cities for jobs
    for city in all_cities:
                
        # get the jobs that are available for the refugees once in city
        job_vacancy =  G.nodes[ city]['jobs'] - G.nodes[ city]['jobs_to_refugees'] 
        potential_workers = int(work_percentage*G.nodes[city]['refugees']-\
                                G.nodes[city]['jobs_to_refugees'])                  
        if potential_workers > job_vacancy:
            G.nodes[city]['jobs_to_refugees'] += job_vacancy
        else:
            G.nodes[city]['jobs_to_refugees'] += potential_workers
            
        # give to the people not having a job the option to change city
        unemployed_refugees = int(G.nodes[city]['refugees']*work_percentage) \
                                - int(G.nodes[city]['jobs_to_refugees'])
        if unemployed_refugees <=0:
            continue
            
        # decision to change city: refugees, population/area, jobs, unemployment rate
        decision = []
        for each in all_cities:
            presence = G.nodes[each]['refugees']
            #density = G.nodes[each]['size'] * G.nodes[each]['unem']/100
            density = G.nodes[each]['refugees']/G.nodes[each]['size']
            jobs = G.nodes[each]['jobs']
            decision.append( (each,(jobs + presence*10), density))

        # sort by opportunities and density
        sort_opp = sorted(decision, key=lambda tup: tup[1])
        sort_den = sorted(decision, key=lambda tup: tup[2])
        sorted_city = {}
        for i,each in enumerate(sort_opp):
            sorted_city[ each[0]] = i
        for i,each in enumerate(sort_den):
            sorted_city[ each[0]] += len(sort_den) - i
        sorted_city = {k:v for k, v in sorted(sorted_city.items(), key=lambda item: item[1])}
       
        # found coefficient per person
        per_person = sum(sorted_city.values())/unemployed_refugees
        
        # find refugees to move to another city
        moved_refugees = 0
        for i in sorted_city:
            refugees_to_move = int( sorted_city[i]/(per_person*work_percentage))
            G.nodes[i]['refugees'] += refugees_to_move
            moved_refugees += refugees_to_move

        # remove the concentration
        G.nodes[city]['refugees'] -= moved_refugees
        
    if run%10 == 0:
        plt.figure(run/50)
        plt.plot([G.nodes[n]['refugees'] for n in G.nodes])

# %%
nx.draw_networkx(G)
plt.show()

# %%
for i in G.nodes:
    print("City:\t\t",i)
    print("Refugees: \t",G.nodes[i]['refugees'])
    print("Working: \t",G.nodes[i]['jobs_to_refugees'])
    print()
# Out:
# City:		 İstanbul
# Refugees: 	 297225
# Working: 	 50970
#
# City:		 Ankara
# Refugees: 	 266043
# Working: 	 45632
#
# City:		 İzmir
# Refugees: 	 250872
# Working: 	 43023
#
# City:		 Bursa
# Refugees: 	 222093
# Working: 	 38081
#
# City:		 Adana
# Refugees: 	 163016
# Working: 	 27953
#
# City:		 Gaziantep
# Refugees: 	 139726
# Working: 	 23953
#
# City:		 Konya
# Refugees: 	 159225
# Working: 	 27300
#
# City:		 Antalya
# Refugees: 	 188122
# Working: 	 32265
#
# City:		 Trabzon
# Refugees: 	 38514
# Working: 	 6600
#
# City:		 Diyarbakır
# Refugees: 	 49112
# Working: 	 8420
#
# City:		 Samsun
# Refugees: 	 84002
# Working: 	 14400
#
# City:		 Kayseri
# Refugees: 	 174150
# Working: 	 29860
#
# City:		 Eskişehir
# Refugees: 	 54877
# Working: 	 9400
#
# City:		 Kocaeli
# Refugees: 	 232690
# Working: 	 39906
#
# City:		 Malatya
# Refugees: 	 26145
# Working: 	 4477
#
# City:		 Şanlıurfa
# Refugees: 	 22056
# Working: 	 3767
#
# City:		 Erzurum
# Refugees: 	 18722
# Working: 	 3200
#
# City:		 Kahramanmaraş
# Refugees: 	 962
# Working: 	 153
#
# City:		 Denizli
# Refugees: 	 110223
# Working: 	 18900
#
# City:		 Van
# Refugees: 	 7185
# Working: 	 1230
#
# City:		 Hatay
# Refugees: 	 29222
# Working: 	 5000
#
# City:		 Batman
# Refugees: 	 3727
# Working: 	 637
#
# City:		 Sakarya
# Refugees: 	 199489
# Working: 	 34200
#
# City:		 Rize
# Refugees: 	 7656
# Working: 	 1300
#
# City:		 Elazığ
# Refugees: 	 18140
# Working: 	 3100
#
# City:		 Sivas
# Refugees: 	 18163
# Working: 	 3100
#
# City:		 Balıkesir
# Refugees: 	 49032
# Working: 	 8400
#
# City:		 Manisa
# Refugees: 	 63649
# Working: 	 10900
#
# City:		 Adıyaman
# Refugees: 	 -5566
# Working: 	 -956
#
# City:		 Kırıkkale
# Refugees: 	 63
# Working: 	 0
#
# City:		 Aydın
# Refugees: 	 63581
# Working: 	 10900
#
# City:		 Kütahya
# Refugees: 	 22781
# Working: 	 3900
#
# City:		 Çorum
# Refugees: 	 8785
# Working: 	 1500
#
# City:		 Isparta
# Refugees: 	 12334
# Working: 	 2100
#
# City:		 Zonguldak
# Refugees: 	 11739
# Working: 	 2000
#
# City:		 Ordu
# Refugees: 	 14653
# Working: 	 2500
#
# City:		 Uşak
# Refugees: 	 5302
# Working: 	 900
#
# City:		 Tokat
# Refugees: 	 8851
# Working: 	 1500
#
# City:		 Erzincan
# Refugees: 	 5299
# Working: 	 900
#
# City:		 Karabük
# Refugees: 	 3571
# Working: 	 600
#
# City:		 Edirne
# Refugees: 	 21635
# Working: 	 3700
#
# City:		 Tekirdağ
# Refugees: 	 107915
# Working: 	 18500
#
# City:		 Karaman
# Refugees: 	 5311
# Working: 	 900
#
# City:		 Giresun
# Refugees: 	 8824
# Working: 	 1500
#
# City:		 Bolu
# Refugees: 	 10585
# Working: 	 1800
#
# City:		 Kırşehir
# Refugees: 	 101
# Working: 	 0
#
# City:		 Niğde
# Refugees: 	 7090
# Working: 	 1200
#
# City:		 Yozgat
# Refugees: 	 5285
# Working: 	 900
#
# City:		 Ağrı
# Refugees: 	 77
# Working: 	 0
#
# City:		 Çanakkale
# Refugees: 	 25707
# Working: 	 4400
#
# City:		 Amasya
# Refugees: 	 8784
# Working: 	 1500
#
# City:		 Muş
# Refugees: 	 1787
# Working: 	 300
#
# City:		 Kilis
# Refugees: 	 -15667
# Working: 	 -2697
#
# City:		 Bingöl
# Refugees: 	 1250
# Working: 	 200
#
# City:		 Hakkari
# Refugees: 	 104
# Working: 	 0
#
# City:		 Kars
# Refugees: 	 2408
# Working: 	 400
#
# City:		 Nevşehir
# Refugees: 	 14629
# Working: 	 2500
#
# City:		 Çankırı
# Refugees: 	 2948
# Working: 	 500
#
# City:		 Mardin
# Refugees: 	 -5149
# Working: 	 -890
#
# City:		 Kastamonu
# Refugees: 	 4189
# Working: 	 700
#
# City:		 Burdur
# Refugees: 	 3582
# Working: 	 600
#
# City:		 Bitlis
# Refugees: 	 290
# Working: 	 43
#
# City:		 Kırklareli
# Refugees: 	 8805
# Working: 	 1500
#
# City:		 Muğla
# Refugees: 	 112954
# Working: 	 19366
#
# City:		 Bilecik
# Refugees: 	 4724
# Working: 	 800
#
# City:		 Sinop
# Refugees: 	 4711
# Working: 	 800
#
# City:		 Gümüşhane
# Refugees: 	 99
# Working: 	 0
#
# City:		 Tunceli
# Refugees: 	 106
# Working: 	 0
#
# City:		 Artvin
# Refugees: 	 2381
# Working: 	 400
#
# City:		 Siirt
# Refugees: 	 -787
# Working: 	 -147
#
# City:		 Bayburt
# Refugees: 	 620
# Working: 	 100
#
# City:		 Osmaniye
# Refugees: 	 1891
# Working: 	 322
#
# City:		 Yalova
# Refugees: 	 18696
# Working: 	 3200
#
# City:		 Ardahan
# Refugees: 	 640
# Working: 	 100
#
# City:		 Bartın
# Refugees: 	 36
# Working: 	 0
#
# City:		 Düzce
# Refugees: 	 9986
# Working: 	 1700
#
# City:		 Aksaray
# Refugees: 	 12919
# Working: 	 2200
#
# City:		 Şırnak
# Refugees: 	 -2184
# Working: 	 -382
#
# City:		 Afyonkarahisar
# Refugees: 	 22254
# Working: 	 3800
#
# City:		 Mersin
# Refugees: 	 119615
# Working: 	 20500
#
# City:		 Iğdır
# Refugees: 	 86
# Working: 	 0
